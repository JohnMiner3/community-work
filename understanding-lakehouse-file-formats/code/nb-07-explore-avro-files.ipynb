# %%
#******************************************************
#*
#* Name:         nb-07-explore-avro-files
#*     
#* Design Phase:
#*     Author:   John Miner
#*     Date:     12-04-2024
#*     Purpose:  Shortcut vs dataframe commands.
#*               Managed vs unmanaged tables.
#* 
#******************************************************/
# Out:
# StatementMeta(, b28e61f8-6919-4645-9c1c-b01631ce7bb5, 7, Finished, Available, Finished)

# %%
# %%sql
#
#  --
#  --  1 - Create managed AVRO table
#  --
#
# -- del
# drop table if exists avro_stocks_ex1;
#
# -- add
#  create table if not exists avro_stocks_ex1 as
#      select * from avro.`Files/Stocks/all_stock_data.avro`;
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 3, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# --
# --  2 - show data
# --
#
# select * from avro_stocks_ex1 limit 10
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 4, Finished, Available, Finished)
# <Spark SQL result set with 10 rows and 11 fields>

# %%
# %%sql
#
# --
# -- 3 - get table info
# --
#
# describe table extended avro_stocks_ex1
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 5, Finished, Available, Finished)
# <Spark SQL result set with 19 rows and 3 fields>

# %%
# %%sql
#
#  --
#  --  4 - Create unmanaged AVRO table
#  --
#
# -- del
# drop table if exists avro_stocks_ex2;
#
# -- add
# create table if not exists avro_stocks_ex2
# using avro
# location "Files/Stocks/all_stock_data.avro"
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 7, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# --
# -- 5 - get table info
# --
#
# describe table extended avro_stocks_ex2
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 8, Finished, Available, Finished)
# <Spark SQL result set with 26 rows and 3 fields>

# %%
# %%sql
#
# --
# -- 6 - show sample records
# --
#
# select * from avro_stocks_ex2 limit 10
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 9, Finished, Available, Finished)
# <Spark SQL result set with 10 rows and 11 fields>

# %%
# %%sql
#
# --
# --  7 - counts should be the same regardless of format
# --
#
# select 'managed table using sql', count(*) as rec_cnt from avro_stocks_ex1
# union
# select 'unmanaged table using sql', count(*) as rec_cnt from avro_stocks_ex2
# Out:
# StatementMeta(, 234bf486-7707-4f54-b594-ed262b6c0a50, 10, Finished, Available, Finished)
# <Spark SQL result set with 2 rows and 2 fields>
