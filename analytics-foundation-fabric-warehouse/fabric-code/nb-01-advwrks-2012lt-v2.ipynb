-- %% [markdown]
-- <font size="5"> Schema 1 - [raw]</font>

-- %%
CREATE SCHEMA [raw] AUTHORIZATION [dbo];

-- %% [markdown]
-- <font size="5"> Table 1 - [raw].[Customer]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[Customer];
go

--
-- Create new table
--

CREATE TABLE [raw].[Customer]
(	[CustomerID] [int] NULL,
	[NameStyle] [bit] NULL,
	[Title] [varchar](8) NULL,
	[FirstName] [varchar](50) NULL,
	[MiddleName] [varchar](50) NULL,
	[LastName] [varchar](50) NULL,
	[Suffix] [varchar](10) NULL,
	[CompanyName] [varchar](128) NULL,
	[SalesPerson] [varchar](256) NULL,
	[EmailAddress] [varchar](50) NULL,
	[Phone] [varchar](25) NULL,
	[PasswordHash] [varchar](128) NULL,
	[PasswordSalt] [varchar](10) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 2 - [raw].[ProductCategory]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[ProductCategory];
go

--
-- Create new table
--

CREATE TABLE [raw].[ProductCategory]
(	[ProductCategoryID] [int] NULL,
	[ParentProductCategoryID] [int] NULL,
	[Name] [varchar](50) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 3 - [raw].[Product]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[Product];
go

--
-- Create new table
--

CREATE TABLE [raw].[Product]
(	[ProductID] [int] NULL,
	[Name] [varchar](50) NULL,
	[ProductNumber] [varchar](25) NULL,
	[Color] [varchar](15) NULL,
	[StandardCost] [decimal](18, 4) NULL,
	[ListPrice] [decimal](18, 4) NULL,
	[Size] [varchar](5) NULL,
	[Weight] [decimal](8, 2) NULL,
	[ProductCategoryID] [int] NULL,
	[ProductModelID] [int] NULL,
	[SellStartDate] [datetime2](6) NULL,
	[SellEndDate] [datetime2](6) NULL,
	[DiscontinuedDate] [datetime2](6) NULL,
	[ThumbNailPhoto] [varbinary](8000) NULL,
	[ThumbnailPhotoFileName] [varchar](50) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 4 - [raw].[ProductDescription]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[ProductDescription];
go

--
-- Create new table
--

CREATE TABLE [raw].[ProductDescription]
(	[ProductDescriptionID] [int] NULL,
	[Description] [varchar](4000) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 5 - [raw].[ProductModel]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[ProductModel];
go

--
-- Create new table
--

CREATE TABLE [raw].[ProductModel]
(	[ProductModelID] [int] NULL,
	[Name] [varchar](50) NULL,
	[CatalogDescription] [varchar](4000),
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 6 - [raw].[ProductModelProductDescription]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[ProductModelProductDescription];
go

--
-- Create new table
--

CREATE TABLE [raw].[ProductModelProductDescription]
(	[ProductModelID] [int] NULL,
	[ProductDescriptionID] [int] NULL,
	[Culture] [char](6) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 7 - [raw].[BuildVersion]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[BuildVersion];
go

--
-- Create new table
--

CREATE TABLE [raw].[BuildVersion]
(	[SystemInformationID] [smallint] NULL,
	[Database Version] [varchar](25) NULL,
	[VersionDate] [datetime2](6) NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 8 - [raw].[ErrorLog]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[ErrorLog];
go

--
-- Create new table
--

CREATE TABLE [raw].[ErrorLog]
(	[ErrorLogID] [int] NULL,
	[ErrorTime] [datetime2](6) NULL,
	[UserName] [varchar](128) NULL,
	[ErrorNumber] [int] NULL,
	[ErrorSeverity] [int] NULL,
	[ErrorState] [int] NULL,
	[ErrorProcedure] [varchar](126) NULL,
	[ErrorLine] [int] NULL,
	[ErrorMessage] [varchar](4000) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 9 - [raw].[Address]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[Address];
go

--
-- Create new table
--

CREATE TABLE [raw].[Address]
(	[AddressID] [int] NULL,
	[AddressLine1] [varchar](60) NULL,
	[AddressLine2] [varchar](60) NULL,
	[City] [varchar](30) NULL,
	[StateProvince] [varchar](50) NULL,
	[CountryRegion] [varchar](50) NULL,
	[PostalCode] [varchar](15) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 10 - [raw].[CustomerAddress]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[CustomerAddress];
go

--
-- Create new table
--

CREATE TABLE [raw].[CustomerAddress]
(	[CustomerID] [int] NULL,
	[AddressID] [int] NULL,
	[AddressType] [varchar](50) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 11 - [raw].[SalesOrderDetail]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[SalesOrderDetail];
go

--
-- Create new table
--

CREATE TABLE [raw].[SalesOrderDetail]
(	[SalesOrderID] [int] NULL,
	[SalesOrderDetailID] [int] NULL,
	[OrderQty] [smallint] NULL,
	[ProductID] [int] NULL,
	[UnitPrice] [decimal](18, 4) NULL,
	[UnitPriceDiscount] [decimal](18, 4) NULL,
	[LineTotal] [varchar](4000),
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 12 - [raw].[SalesOrderHeader]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [raw].[SalesOrderHeader];
go


--
-- Create new table
--

CREATE TABLE [raw].[SalesOrderHeader]
(	[SalesOrderID] [int] NULL,
	[RevisionNumber] [smallint] NULL,
	[OrderDate] [datetime2](6) NULL,
	[DueDate] [datetime2](6) NULL,
	[ShipDate] [datetime2](6) NULL,
	[Status] [smallint] NULL,
	[OnlineOrderFlag] [bit] NULL,
	[SalesOrderNumber] [varchar](4000),
	[PurchaseOrderNumber] [varchar](25) NULL,
	[AccountNumber] [varchar](15) NULL,
	[CustomerID] [int] NULL,
	[ShipToAddressID] [int] NULL,
	[BillToAddressID] [int] NULL,
	[ShipMethod] [varchar](50) NULL,
	[CreditCardApprovalCode] [varchar](15) NULL,
	[SubTotal] [decimal](18, 4) NULL,
	[TaxAmt] [decimal](18, 4) NULL,
	[Freight] [decimal](18, 4) NULL,
	[TotalDue] [varchar](4000),
	[Comment] [varchar](4000) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 13 - [stage0].[SalesOrderDetail]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [stage0].[SalesOrderDetail];
go

--
-- Create new table
--

CREATE TABLE [stage0].[SalesOrderDetail]
(	[SalesOrderID] [int] NULL,
	[SalesOrderDetailID] [int] NULL,
	[OrderQty] [smallint] NULL,
	[ProductID] [int] NULL,
	[UnitPrice] [decimal](18, 4) NULL,
	[UnitPriceDiscount] [decimal](18, 4) NULL,
	[LineTotal] [varchar](4000),
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go

-- %% [markdown]
-- <font size="5"> Table 14 - [stage0].[SalesOrderHeader]</font>

-- %%
--
-- Delete existing table
--

drop table if exists [stage0].[SalesOrderHeader];
go


--
-- Create new table
--

CREATE TABLE [stage0].[SalesOrderHeader]
(	[SalesOrderID] [int] NULL,
	[RevisionNumber] [smallint] NULL,
	[OrderDate] [datetime2](6) NULL,
	[DueDate] [datetime2](6) NULL,
	[ShipDate] [datetime2](6) NULL,
	[Status] [smallint] NULL,
	[OnlineOrderFlag] [bit] NULL,
	[SalesOrderNumber] [varchar](4000),
	[PurchaseOrderNumber] [varchar](25) NULL,
	[AccountNumber] [varchar](15) NULL,
	[CustomerID] [int] NULL,
	[ShipToAddressID] [int] NULL,
	[BillToAddressID] [int] NULL,
	[ShipMethod] [varchar](50) NULL,
	[CreditCardApprovalCode] [varchar](15) NULL,
	[SubTotal] [decimal](18, 4) NULL,
	[TaxAmt] [decimal](18, 4) NULL,
	[Freight] [decimal](18, 4) NULL,
	[TotalDue] [varchar](4000),
	[Comment] [varchar](4000) NULL,
	[rowguid] [uniqueidentifier] NULL,
	[ModifiedDate] [datetime2](6) NULL
);
go
