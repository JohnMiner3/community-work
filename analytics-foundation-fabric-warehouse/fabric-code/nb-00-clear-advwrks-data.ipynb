-- %% [markdown]
-- <font size="5"> Table 1 - [raw].[Customer]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[Customer];
go

-- %% [markdown]
-- <font size="5"> Table 2 - [raw].[ProductCategory]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[ProductCategory];
go

-- %% [markdown]
-- <font size="5"> Table 3 - [raw].[Product]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[Product];
go

-- %% [markdown]
-- <font size="5"> Table 4 - [raw].[ProductDescription]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[ProductDescription];
go

-- %% [markdown]
-- <font size="5"> Table 5 - [raw].[ProductModel]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[ProductModel];
go

-- %% [markdown]
-- <font size="5"> Table 6 - [raw].[ProductModelProductDescription]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[ProductModelProductDescription];
go

-- %% [markdown]
-- <font size="5"> Table 7 - [raw].[BuildVersion]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[BuildVersion];
go

-- %% [markdown]
-- <font size="5"> Table 8 - [raw].[ErrorLog]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[ErrorLog];
go

-- %% [markdown]
-- <font size="5"> Table 9 - [raw].[Address]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[Address];
go

-- %% [markdown]
-- <font size="5"> Table 10 - [raw].[CustomerAddress]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[CustomerAddress];
go

-- %% [markdown]
-- <font size="5"> Table 11 - [raw].[SalesOrderDetail]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[SalesOrderDetail];
go

-- %% [markdown]
-- <font size="5"> Table 12 - [raw].[SalesOrderHeader]</font>

-- %%
--
-- Truncate existing table
--

truncate table [raw].[SalesOrderHeader];
go

-- %% [markdown]
-- <font size="5"> Table 13 - [stage0].[SalesOrderDetail]</font>

-- %%
--
-- Truncate existing table
--

truncate table [stage0].[SalesOrderDetail];
go

-- %% [markdown]
-- <font size="5"> Table 15 - [meta].[Logs]</font>

-- %%
--
-- Truncate existing table
--

truncate table [meta].[Logs];
go

-- %%
--
--  See Koen Verbeeck - https://tinyurl.com/y4x7u3wu
--

DECLARE @SqlStmt NVARCHAR(MAX);
SELECT @SqlStmt = COALESCE(@SqlStmt + ' UNION ALL ','')
    + 'SELECT '
    + '''' + QUOTENAME(SCHEMA_NAME(s.schema_id))
    + '.' + QUOTENAME(s.[name]) + '''' + ' AS [TableName], COUNT(*) AS [RowCount] FROM '
    + QUOTENAME(SCHEMA_NAME(s.schema_id))
    + '.' + QUOTENAME(s.[name])
FROM sys.objects AS s
WHERE s.[type] = 'U' AND s.is_ms_shipped = 0x0
ORDER BY SCHEMA_NAME(s.schema_id), s.[name];

EXEC sp_executesql @SqlStmt;
