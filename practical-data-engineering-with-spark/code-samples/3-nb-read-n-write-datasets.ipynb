# %% [markdown]
# <img src= "/files/tables/avatar.jpg" width="100" height="100" />
#
# ```
#
# Name:         3-nb-read-n-write-data
#
# Design Phase:
#     Author:   John Miner
#     Date:     12-01-2020
#     Purpose:  How to read and write with spark dataframes
#
# Learning Guide:
#     1 - Create local data lake
#     2 - Read + Write CSV files (infer data)
#     3 - Read + Write CSV files (infer data)
#     4 - Read + Write Parquet Files
#     5 - Read + Write TSV files
#
# ```

# %%
# %run "./n-tool-box-code"

# %%
#
# 1 - Create sample data lake
#

# remove existing
try:
  dbutils.fs.rm("/lake", recurse=True)  
except:
  pass

# root
dbutils.fs.mkdirs("/lake")

# amazon data
dbutils.fs.mkdirs("/lake/bronze/amazon")

# diamond data
dbutils.fs.mkdirs("/lake/bronze/diamonds")

# power plant
dbutils.fs.mkdirs("/lake/bronze/power")

# weather
dbutils.fs.mkdirs("/lake/bronze/weather")

# folders
dbutils.fs.ls("/lake/bronze")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/lake/bronze/amazon/&#39;, name=&#39;amazon/&#39;, size=0, modificationTime=1651015217000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/diamonds/&#39;, name=&#39;diamonds/&#39;, size=0, modificationTime=1651015217000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/power/&#39;, name=&#39;power/&#39;, size=0, modificationTime=1651015217000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/weather/&#39;, name=&#39;weather/&#39;, size=0, modificationTime=1651015217000)]</div>

# %%
#
# 2 - Read + write csv data - no schema
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Two files
dbutils.fs.ls("/databricks-datasets/weather")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [FileInfo(path=&#39;dbfs:/databricks-datasets/weather/README.weather_history.md&#39;, name=&#39;README.weather_history.md&#39;, size=750, modificationTime=1540403318000),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/weather/high_temps&#39;, name=&#39;high_temps&#39;, size=19180, modificationTime=1540403358000),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/weather/low_temps&#39;, name=&#39;low_temps&#39;, size=19180, modificationTime=1540403342000)]</div>

# %%
# low temps
dbutils.fs.head("/databricks-datasets/weather/low_temps", 500)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 500 bytes]
# Out[222]: &#39;&#34;date&#34;,&#34;temp&#34;\n2015-01-01,26\n2015-01-02,32\n2015-01-03,35\n2015-01-04,38\n2015-01-05,49\n2015-01-06,43\n2015-01-07,42\n2015-01-08,35\n2015-01-09,38\n2015-01-10,43\n2015-01-11,45\n2015-01-12,40\n2015-01-13,37\n2015-01-14,33\n2015-01-15,34\n2015-01-16,42\n2015-01-17,38\n2015-01-18,45\n2015-01-19,43\n2015-01-20,38\n2015-01-21,31\n2015-01-22,43\n2015-01-23,47\n2015-01-24,52\n2015-01-25,45\n2015-01-26,43\n2015-01-27,47\n2015-01-28,41\n2015-01-29,38\n2015-01-30,34\n2015-01-31,38\n2015-02-01,40\n2015-02-02,41\n2015-02-03,42\n2015-02-04&#39;</div>

# %%
# high temps
dbutils.fs.head("/databricks-datasets/weather/high_temps", 500)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 500 bytes]
# Out[223]: &#39;&#34;date&#34;,&#34;temp&#34;\n2015-01-01,42\n2015-01-02,42\n2015-01-03,41\n2015-01-04,51\n2015-01-05,54\n2015-01-06,54\n2015-01-07,46\n2015-01-08,46\n2015-01-09,50\n2015-01-10,46\n2015-01-11,49\n2015-01-12,52\n2015-01-13,49\n2015-01-14,43\n2015-01-15,46\n2015-01-16,53\n2015-01-17,56\n2015-01-18,57\n2015-01-19,50\n2015-01-20,50\n2015-01-21,45\n2015-01-22,49\n2015-01-23,54\n2015-01-24,58\n2015-01-25,63\n2015-01-26,61\n2015-01-27,52\n2015-01-28,54\n2015-01-29,54\n2015-01-30,47\n2015-01-31,45\n2015-02-01,49\n2015-02-02,52\n2015-02-03,50\n2015-02-04&#39;</div>

# %%
# read in low temps
path1 = "/databricks-datasets/weather/low_temps"
df1 = (
  spark.read                    
  .option("sep", ",")        
  .option("header", "true")
  .option("inferSchema", "true")  
  .csv(path1)               
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# rename columns
df1 = df1.withColumnRenamed("temp", "low_temp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show top 5 rows
display(df1.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>low_temp</th></tr></thead><tbody><tr><td>2015-01-01T00:00:00.000+0000</td><td>26</td></tr><tr><td>2015-01-02T00:00:00.000+0000</td><td>32</td></tr><tr><td>2015-01-03T00:00:00.000+0000</td><td>35</td></tr><tr><td>2015-01-04T00:00:00.000+0000</td><td>38</td></tr><tr><td>2015-01-05T00:00:00.000+0000</td><td>49</td></tr></tbody></table></div>

# %%
# read in high temps
path2 = "/databricks-datasets/weather/high_temps"
df2 = (
  spark.read                    
  .option("sep", ",")        
  .option("header", "true")
  .option("inferSchema", "true")  
  .csv(path2)               
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# rename columns
df2 = df2.withColumnRenamed("temp", "high_temp")
df2 = df2.withColumnRenamed("date", "date2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show top 5 rows
display(df2.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date2</th><th>high_temp</th></tr></thead><tbody><tr><td>2015-01-01T00:00:00.000+0000</td><td>42</td></tr><tr><td>2015-01-02T00:00:00.000+0000</td><td>42</td></tr><tr><td>2015-01-03T00:00:00.000+0000</td><td>41</td></tr><tr><td>2015-01-04T00:00:00.000+0000</td><td>51</td></tr><tr><td>2015-01-05T00:00:00.000+0000</td><td>54</td></tr></tbody></table></div>

# %%
# join + drop col
df3 = df1.join(df2, df1["date"] == df2["date2"]).drop("date2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show top 5 rows
display(df3.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>low_temp</th><th>high_temp</th></tr></thead><tbody><tr><td>2015-01-01T00:00:00.000+0000</td><td>26</td><td>42</td></tr><tr><td>2015-01-02T00:00:00.000+0000</td><td>32</td><td>42</td></tr><tr><td>2015-01-03T00:00:00.000+0000</td><td>35</td><td>41</td></tr><tr><td>2015-01-04T00:00:00.000+0000</td><td>38</td><td>51</td></tr><tr><td>2015-01-05T00:00:00.000+0000</td><td>49</td><td>54</td></tr></tbody></table></div>

# %%
# Number of partitions
df3.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 1</div>

# %%
# Write out csv file
dst_path = "/lake/bronze/weather/temp"
(
  df3.repartition(1).write
    .format("csv")
    .mode("overwrite")
    .save(dst_path)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show results
dbutils.fs.ls("/lake/bronze/weather/temp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [FileInfo(path=&#39;dbfs:/lake/bronze/weather/temp/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0, modificationTime=1651015442000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/weather/temp/_committed_5103082464251815936&#39;, name=&#39;_committed_5103082464251815936&#39;, size=112, modificationTime=1651015442000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/weather/temp/_started_5103082464251815936&#39;, name=&#39;_started_5103082464251815936&#39;, size=0, modificationTime=1651015442000),
#  FileInfo(path=&#39;dbfs:/lake/bronze/weather/temp/part-00000-tid-5103082464251815936-dce87d03-545c-41df-89a2-0350f6d09f16-36-1-c000.csv&#39;, name=&#39;part-00000-tid-5103082464251815936-dce87d03-545c-41df-89a2-0350f6d09f16-36-1-c000.csv&#39;, size=42439, modificationTime=1651015442000)]</div>

# %%
# create single file
unwanted_file_cleanup("/lake/bronze/weather/temp/", "/lake/bronze/weather/temperature-data.csv", "csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: True</div>

# %%
dbutils.fs.ls("/lake/bronze/weather/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [FileInfo(path=&#39;dbfs:/lake/bronze/weather/temperature-data.csv&#39;, name=&#39;temperature-data.csv&#39;, size=42439, modificationTime=1651015493000)]</div>

# %%
#
# 3 - Read + write csv data - schema defined
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# https://spark.apache.org/docs/latest/sql-ref-datatypes.html
# https://vincent.doba.fr/posts/20211004_spark_data_description_language_for_defining_spark_schema/

# define DDL
schema = "_c0 INTEGER, carat DOUBLE, cut STRING, color STRING, clarity STRING, depth DOUBLE, table DOUBLE, price INTEGER, x DOUBLE, y DOUBLE, z DOUBLE" 

# specify path
path = "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"

# read in file
df = (spark.read.format("csv").option("header", "true").schema(schema).load(path))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# show top 5 rows
display(df.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>1</td><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td></tr><tr><td>2</td><td>0.21</td><td>Premium</td><td>E</td><td>SI1</td><td>59.8</td><td>61.0</td><td>326</td><td>3.89</td><td>3.84</td><td>2.31</td></tr><tr><td>3</td><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td></tr><tr><td>4</td><td>0.29</td><td>Premium</td><td>I</td><td>VS2</td><td>62.4</td><td>58.0</td><td>334</td><td>4.2</td><td>4.23</td><td>2.63</td></tr><tr><td>5</td><td>0.31</td><td>Good</td><td>J</td><td>SI2</td><td>63.3</td><td>58.0</td><td>335</td><td>4.34</td><td>4.35</td><td>2.75</td></tr></tbody></table></div>

# %%
# Write out csv file
dst_path = "/lake/bronze/diamonds/temp"
(
  df.repartition(1).write
    .format("parquet")
    .mode("overwrite")
    .save(dst_path)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create single file
unwanted_file_cleanup("/lake/bronze/diamonds/temp/", "/lake/bronze/diamonds/diamonds-data.parquet", "parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: True</div>

# %%
dbutils.fs.ls("/lake/bronze/diamonds/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: [FileInfo(path=&#39;dbfs:/lake/bronze/diamonds/diamonds-data.parquet&#39;, name=&#39;diamonds-data.parquet&#39;, size=731642, modificationTime=1651015589000)]</div>

# %%
#
# 4 - Read + write parquet file format
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Show files
lst = dbutils.fs.ls("/databricks-datasets/amazon/test4K")
print(lst, "\n\n", len(lst))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0, modificationTime=1472793653000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00000-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00000-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=117538, modificationTime=1472793653000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00001-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00001-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=123797, modificationTime=1472793654000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00002-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00002-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=122591, modificationTime=1472793654000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00003-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00003-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=114454, modificationTime=1472793655000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00004-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00004-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=111231, modificationTime=1472793655000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00005-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00005-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=114202, modificationTime=1472793656000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00006-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00006-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=129835, modificationTime=1472793656000), FileInfo(path=&#39;dbfs:/databricks-datasets/amazon/test4K/part-r-00007-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, name=&#39;part-r-00007-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet&#39;, size=128753, modificationTime=1472793657000)]
#
#  9
# </div>

# %%
# read in amazon product data
path4 = "/databricks-datasets/amazon/test4K"
df4 = (
  spark.read                    
  .parquet(path4)               
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df4.head(500))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>asin</th><th>brand</th><th>helpful</th><th>img</th><th>price</th><th>rating</th><th>review</th><th>time</th><th>title</th><th>user</th></tr></thead><tbody><tr><td>B00014JKG0</td><td>Nature&#39;s Gate</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/31RIumF2GIL._SY300_.jpg</td><td>10.02</td><td>5.0</td><td>I bought this for my gf and she loves it. Unlike other lotions you don't need several coats for dry shin and it smells nice too. The oils leave her skin smooth for a whole day not just an hr or 2. I'd recommend this to anyone with any skin type, you can't go wrong with this stuff and I'll be ordering more when it runs out.</td><td>1339372800</td><td>Nature's Gate Tea Tree Moisturizing Lotion for Irritated, Distressed Skin, 18-Ounce Pump Bottle</td><td>A1E57U9XDQCSKC</td></tr><tr><td>B000L596FE</td><td>Luxor Pro</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/41xj70ovtmL._SY300_.jpg</td><td>8.97</td><td>5.0</td><td>My 5 yr old wakes up with terribly knotted hair & this brush glides right through it. It truly is some kind of magic! I'd love to give these brushes out as party favors for her birthday :-)</td><td>1388620800</td><td>The Wet Brush Detangling Shower Brush, Colors Vary</td><td>AO95JTORR64XZ</td></tr><tr><td>B008FXKOI2</td><td>Greenies</td><td>List(2, 2)</td><td>http://ecx.images-amazon.com/images/I/51ocmMt8tfL._SY300_.jpg</td><td>4.72</td><td>4.0</td><td>A healthier choice than the Friskies line for kitty crunchies.  My vet uses this brand, which is why I switched.I alternate between the chicken skin & fur and the salmon hairball control, depending on what kind of dry food currently in use.  These smartbites are easier for my cat to chew than the dental ones, though I will use the dental every other month or so.Only negative: the volume seems less than from a year ago on the smartbites, but that's in the brick & mortar stores, also.</td><td>1385856000</td><td>Greenies Smartbites Cat Treats, 2.1-Ounce</td><td>AKLVHFSQRFQL7</td></tr><tr><td>B000UJW676</td><td>Nelson</td><td>List(2, 2)</td><td>http://ecx.images-amazon.com/images/I/51M2elTqCpL._SY300_.jpg</td><td>6.39</td><td>1.0</td><td>Item fell short of expectations, it did not fit my 3/4&#34; hose as it stated it would and that is why I purchased it</td><td>1376092800</td><td>Nelson Brass/Metal Hose Repair Clamp Connector Female 50521</td><td>A13KOZOGKOF5R4</td></tr><tr><td>B004TK0IG8</td><td>Stanley</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/41OpTlmDsKL._SX300_.jpg</td><td>99.99</td><td>4.0</td><td>It took much work to flatten the backs of the larger (1&#34; and 3/4&#34;) chisels.  The 1&#34; chisel has a major grinding flaw near the socket, but not worth returning, since I only needed to flatten the first inch or so to get a good polish. These stay sharp longer than my Irwin chisels, but no where near as long as my Veritas chisels, but the price was right for the set. Once flattened and honed, they are a pleasure to use. These chisels are well balanced easy to hold with just the fingers.I can't compare them to L.N. since I don't own any.  Great chisels for a serious hobbyist.</td><td>1355443200</td><td>Stanley 16-791 Sweetheart 750 Series Socket Chisel 4 Piece Set</td><td>A19RQK364II90W</td></tr><tr><td>B00D12OBEU</td><td>MSI</td><td>List(1, 1)</td><td>http://ecx.images-amazon.com/images/I/51X0FrnHE6L._SX300_.jpg</td><td>150.23</td><td>2.0</td><td>I have one sata HDD. I bought an SSD and my motherboard sometimes doesn't recognize it, only the first HDD. Today I bought one optical drive and I've gotten the same problem.In brief, this motherboard does not work good with two sata devices.If I would had known this I would have bought an asus rampagePD: I updated bios and nothing.</td><td>1393632000</td><td>MSI Computer Corp. Motherboard ATX DDR3 1333 LGA 1150 Motherboards Z87-G45 GAMING</td><td>A30X ...

# %%
# reduce columns
df5 = df4.select("asin", "brand", "price", "rating")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Write out csv file
dst_path = "/lake/bronze/amazon/temp"
(
  df5.repartition(1).write
    .format("parquet")
    .mode("overwrite")
    .save(dst_path)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create single file
unwanted_file_cleanup("/lake/bronze/amazon/temp/", "/lake/bronze/amazon/product-data.parquet", "parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: True</div>

# %%
dbutils.fs.ls("/lake/bronze/amazon/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [FileInfo(path=&#39;dbfs:/lake/bronze/amazon/product-data.parquet&#39;, name=&#39;product-data.parquet&#39;, size=88684, modificationTime=1651015671000)]</div>

# %%
#
# 5 - Read + write tsv file format
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Data types

# Define schema
src_schema = "AT FLOAT, V FLOAT, AP FLOAT, RH FLOAT, PE FLOAT"
src_path = "/databricks-datasets/power-plant/data/*.tsv"

df6 = (spark.read 
  .format("csv") 
  .schema(src_schema)
  .option("header", "true") 
  .option("delimiter", "\t")
  .option("quote", "")
  .load(src_path)  
  .repartition(1)
  )
display(df6)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AT</th><th>V</th><th>AP</th><th>RH</th><th>PE</th></tr></thead><tbody><tr><td>14.96</td><td>41.76</td><td>1024.07</td><td>73.17</td><td>463.26</td></tr><tr><td>25.18</td><td>62.96</td><td>1020.04</td><td>59.08</td><td>444.37</td></tr><tr><td>5.11</td><td>39.4</td><td>1012.16</td><td>92.14</td><td>488.56</td></tr><tr><td>20.86</td><td>57.32</td><td>1010.24</td><td>76.64</td><td>446.48</td></tr><tr><td>10.82</td><td>37.5</td><td>1009.23</td><td>96.62</td><td>473.9</td></tr><tr><td>26.27</td><td>59.44</td><td>1012.23</td><td>58.77</td><td>443.67</td></tr><tr><td>15.89</td><td>43.96</td><td>1014.02</td><td>75.24</td><td>467.35</td></tr><tr><td>9.48</td><td>44.71</td><td>1019.12</td><td>66.43</td><td>478.42</td></tr><tr><td>14.64</td><td>45.0</td><td>1021.78</td><td>41.25</td><td>475.98</td></tr><tr><td>11.74</td><td>43.56</td><td>1015.14</td><td>70.72</td><td>477.5</td></tr><tr><td>17.99</td><td>43.72</td><td>1008.64</td><td>75.04</td><td>453.02</td></tr><tr><td>20.14</td><td>46.93</td><td>1014.66</td><td>64.22</td><td>453.99</td></tr><tr><td>24.34</td><td>73.5</td><td>1011.31</td><td>84.15</td><td>440.29</td></tr><tr><td>25.71</td><td>58.59</td><td>1012.77</td><td>61.83</td><td>451.28</td></tr><tr><td>26.19</td><td>69.34</td><td>1009.48</td><td>87.59</td><td>433.99</td></tr><tr><td>21.42</td><td>43.79</td><td>1015.76</td><td>43.08</td><td>462.19</td></tr><tr><td>18.21</td><td>45.0</td><td>1022.86</td><td>48.84</td><td>467.54</td></tr><tr><td>11.04</td><td>41.74</td><td>1022.6</td><td>77.51</td><td>477.2</td></tr><tr><td>14.45</td><td>52.75</td><td>1023.97</td><td>63.59</td><td>459.85</td></tr><tr><td>13.97</td><td>38.47</td><td>1015.15</td><td>55.28</td><td>464.3</td></tr><tr><td>17.76</td><td>42.42</td><td>1009.09</td><td>66.26</td><td>468.27</td></tr><tr><td>5.41</td><td>40.07</td><td>1019.16</td><td>64.77</td><td>495.24</td></tr><tr><td>7.76</td><td>42.28</td><td>1008.52</td><td>83.31</td><td>483.8</td></tr><tr><td>27.23</td><td>63.9</td><td>1014.3</td><td>47.19</td><td>443.61</td></tr><tr><td>27.36</td><td>48.6</td><td>1003.18</td><td>54.93</td><td>436.06</td></tr><tr><td>27.47</td><td>70.72</td><td>1009.97</td><td>74.62</td><td>443.25</td></tr><tr><td>14.6</td><td>39.31</td><td>1011.11</td><td>72.52</td><td>464.16</td></tr><tr><td>7.91</td><td>39.96</td><td>1023.57</td><td>88.44</td><td>475.52</td></tr><tr><td>5.81</td><td>35.79</td><td>1012.14</td><td>92.28</td><td>484.41</td></tr><tr><td>30.53</td><td>65.18</td><td>1012.69</td><td>41.85</td><td>437.89</td></tr><tr><td>23.87</td><td>63.94</td><td>1019.02</td><td>44.28</td><td>445.11</td></tr><tr><td>26.09</td><td>58.41</td><td>1013.64</td><td>64.58</td><td>438.86</td></tr><tr><td>29.27</td><td>66.85</td><td>1011.11</td><td>63.25</td><td>440.98</td></tr><tr><td>27.38</td><td>74.16</td><td>1010.08</td><td>78.61</td><td>436.65</td></tr><tr><td>24.81</td><td>63.94</td><td>1018.76</td><td>44.51</td><td>444.26</td></tr><tr><td>12.75</td><td>44.03</td><td>1007.29</td><td>89.46</td><td>465.86</td></tr><tr><td>24.66</td><td>63.73</td><td>1011.4</td><td>74.52</td><td>444.37</td></tr><tr><td>16.38</td><td>47.45</td><td>1010.08</td><td>88.86</td><td>450.69</td></tr><tr><td>13.91</td><td>39.35</td><td>1014.69</td><td>75.51</td><td>469.02</td></tr><tr><td>23.18</td><td>51.3</td><td>1012.04</td><td>78.64</td><td>448.86</td></tr><tr><td>22.47</td><td>47.45</td><td>1007.62</td><td>76.65</td><td>447.14</td></tr><tr><td>13.39</td><td>44.85</td><td>1017.24</td><td>80.44</td><td>469.18</td></tr><tr><td>9.28</td><td>41.54</td><td>1018.33</td><td>79.89</td><td>482.8</td></tr><tr><td>11.82</td><td>42.86</td><td>1014.12</td><td>88.28</td><td>476.7</td></tr><tr><td>10.27</td><td>40.64</td><td>1020.63</td><td>84.6</td><td>474.99</td></tr><tr><td>22.92</td><td>63.94</td><td>1019.28</td><td>42.69</td><td>444.22</td></tr><tr><td>16.0</td><td>37.87</td><td>1020.24</td><td>78.41</td><td>4 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Write out csv file
path = "/lake/bronze/power/temp"
(
  df6.repartition(1).write
    .format("parquet")
    .mode("overwrite")
    .save(path)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create single file
unwanted_file_cleanup("/lake/bronze/power/temp/", "/lake/bronze/power/plant-data.parquet", "parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: True</div>

# %%
dbutils.fs.ls("/lake/bronze/power/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: [FileInfo(path=&#39;dbfs:/lake/bronze/power/plant-data.parquet&#39;, name=&#39;plant-data.parquet&#39;, size=422932, modificationTime=1651015694000)]</div>

# %%
#
#  Support file formats
#

# https://spark.apache.org/docs/latest/sql-data-sources.html

# AVRO
# CSV
# JSON
# PARQUET
# TEXT
# JDBC
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
