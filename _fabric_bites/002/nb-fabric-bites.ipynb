# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 19, Finished, Available, Finished)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.6/693.6 kB 36.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
#
#  Import library
#

import sempy_labs as labs
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 21, Finished, Available, Finished)

# %%
#
#  Show non-personal workspaces
#

lst_wkspc = labs.admin.list_workspaces()
lst_wkspc[lst_wkspc['Type'] == 'Workspace']
# Out:
# StatementMeta(, 79077872-86ff-4de2-abeb-d559a05c5bc9, 21, Finished, Available, Finished)
#                                       Id                         Name   State  \
# 0   517e5bc3-fa2a-44e9-9451-67287c391227                     Test 123  Active
# 6   8742d3fd-917c-4983-b173-bd50df60c9f3          ws-aviation-tracker  Active
# 8   b47d5104-7bf4-4b2b-8f95-cf7773bd4ea2        ws-sandbox-playground  Active
# 13  3dc8801f-bb80-490d-b5f0-ad61c7aa1220                ws-file-types  Active
# 14  d5450d60-533b-4d39-aa71-1f8fc34be1d4         ws-snp500-stocks-dev  Active
# 15  8d7ef218-48c2-4db1-b086-13d187d61fdf         ws-snp500-stocks-prd  Active
# 17  b7c974f1-3659-4162-ad1d-21a513eee8f6              ws-big-jons-bbq  Active
# 18  f2b0f1b9-f434-46d9-8f74-bc985dad2143     ws-dev-advwrks-analytics  Active
# 20  2eae3051-bae6-4d7b-9b90-5f4c9dbd40ad  ws-open-mirroring-northwind  Active
# 21  397a3457-9e41-4fbe-96c8-c33c3659bd61              ws-fabric-bites  Active
#
# ...

# %%
#
#  Scan the workspace
#

labs.admin.scan_workspaces(workspace='Test 123')
# Out:
# StatementMeta(, 79077872-86ff-4de2-abeb-d559a05c5bc9, 19, Finished, Available, Finished)
# {'workspaces': [{'id': '517e5bc3-fa2a-44e9-9451-67287c391227',
#    'name': 'Test 123',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': False,
#    'reports': [],
#    'dashboards': [],
#    'datasets': [],
#    'dataflows': [],
#    'datamarts': []}]}

# %%
#
#  Remove the workspace
#

labs.delete_workspace("Test 123")
# Out:
# StatementMeta(, 79077872-86ff-4de2-abeb-d559a05c5bc9, 22, Finished, Available, Finished)
# 🟢 The 'Test 123' workspace has been deleted.

# %%
#
#  List warehouses
#

lst_whs = labs.list_warehouses('ws-fabric-bites')
lst_whs
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 22, Finished, Available, Finished)
#              Warehouse Name                          Warehouse Id  \
# 0    wh_pubs_case_sensitive  f34619ab-bbae-4101-b543-030c387c4a69
# 1  wh_pubs_case_insensitive  32f76597-7ddb-4fb3-8cef-d9dc47c903fd
# 2           wh-fabric-bites  6a545e0c-9121-48a4-8905-0e5262c1f482
#
#                                      Description  \
# 0
# 1  New warehouse with case-insensitive collation
# 2               A new warehouse using sempy labs
#
#                                      Connection Info  \
# 0  abgrhetr4hsurajv2abiablt4q-k42huokbt27e7fwiym6...
# 1  abgrhetr4hsurajv2abiablt4q-k42huokbt27e7fwiym6...
# 2  abgrhetr4hsurajv2abiablt4q-k42huokbt27e7fwiym6...
#
#                    Created Date             Last Updated Time
# 0 2025-03-31 05:20:03.248187900 2025-04-15 16:15:19.548885000
# 1 2025-03-31 20:09:56.838921900 2025-03-31 23:47:11.698113600
# ...

# %%
#
#  Pubs case-insensative warehouse
#

lst_whs['Connection Info'][1]
# Out:
# StatementMeta(, 79077872-86ff-4de2-abeb-d559a05c5bc9, 36, Finished, Available, Finished)
# 'abgrhetr4hsurajv2abiablt4q-k42huokbt27e7fwiym6dmwn5me.datawarehouse.fabric.microsoft.com'

# %%
#
#  Create a new case-insensative warehouse
#

new_wh = labs.create_warehouse(warehouse='wh_fabric_bites', description = 'A new warehouse using sempy labs', workspace='ws-fabric-bites', case_insensitive_collation=True)
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 25, Finished, Available, Finished)
# 🟢 The 'wh_fabric_bites' warehouse has been created within the 'ws-fabric-bites' workspace.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       1 #
#       2 #  Create a new case-insensative warehouse
#       3 #
# ----> 5 new_wh = labs.create_warehouse(warehouse='wh_fabric_bites', description = 'A new warehouse using sempy labs', workspace='ws-fabric-bites', case_insensitive_collation=True)
#
# File /nfs4/pyenv-0cd5d934-1aa8-4fab-8dec-ed2c4b474de0/lib/python3.11/site-packages/sempy_labs/_warehouses.py:68, in create_warehouse(warehouse, description, case_insensitive_collation, workspace)
#      56 response = _base_api(
#      57     request=f"/v1/workspaces/{workspace_id}/warehouses",
#      58     payload=payload,
#    (...)
# ...

# %%
import com.microsoft.spark.fabric
from com.microsoft.spark.fabric.Constants import Constants  

df = spark.read.synapsesql("wh_pubs_case_insensitive.dbo.authors").limit(10)
display(df)
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 35, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b431cada-7a91-4edf-8528-d7826f43dc5d)

# %%
# workspace id
wkspc_id = labs.admin.list_workspaces(workspace='ws-fabric-bites')['Id']

# show case sensativity
df = (
    spark.read.
    option(Constants.WorkspaceId, wkspc_id[0]).
    option(Constants.DatabaseName, "wh_pubs_case_insensitive").
    synapsesql("SELECT name, collation_name FROM sys.databases")
    )
display(df)
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 60, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d22b0ebc-c965-4fbd-8e2d-d2eda41b5c63)

# %%
#
#  Remove the warehouse
#

labs.delete_warehouse(workspace='ws-fabric-bites', name ='wh-fabric-bites')
# Out:
# StatementMeta(, 246ea9d0-bcc3-4192-8e85-6fe8733d8759, 59, Finished, Available, Finished)
# 🟢 The 'wh-fabric-bites' warehouse has been successfully deleted from the 'ws-fabric-bites' workspace.
